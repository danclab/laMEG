# %% [markdown]
# # Laminar model comparison using cross-validation error

# %% [markdown]
# This tutorial demonstrates how to perform laminar inference using model comparison based on cross-validation error as a metric of model fit, described in [Bonaiuto et al., 2018, Non-invasive laminar inference with MEG: Comparison of methods and source inversion algorithms](https://doi.org/10.1016/j.neuroimage.2017.11.068). A 20Hz oscillation is simulated at a particular cortical location in various layers. Source reconstruction is performed using the Empirical Bayesian Beamformer on the simulated sensor data using forward models based on different layer meshes. These models are then compared using cross-validation error. Cross-validation error is computed by fitting the model N times, each time leaving out a certain percentage of the channels and seeing how well the resulting model can predict the signal in those channels
#
# ## Setting up the simulations
#
# Simulations are based on an existing dataset, which is used to define the sampling rate, number of trials, duration of each trial, and the channel layout.

# %%
import os
import shutil
import numpy as np
import nibabel as nib
from matplotlib import colors
import matplotlib.pyplot as plt

from lameg.invert import coregister, invert_ebb
from lameg.simulate import run_current_density_simulation
from lameg.laminar import model_comparison
from lameg.util import get_surface_names, get_fiducial_coords
from lameg.viz import show_surface
import spm_standalone

# Subject information for data to base the simulations on
subj_id = 'sub-104'
ses_id = 'ses-01'

# Fiducial coil coordinates
nas, lpa, rpa = get_fiducial_coords(subj_id, '../test_data/participants.tsv')

# Data file to base simulations on
data_file = os.path.join(
    '../test_data', 
    subj_id,
    'meg',
    ses_id, 
    'spm/spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo.mat'
)

spm = spm_standalone.initialize()

# %% [markdown]
# For source reconstructions, we need an MRI and a surface mesh. The simulations will be based on a forward model using the multilayer mesh, and the model comparison will use each layer mesh

# %%
# Native space MRI to use for coregistration
mri_fname = os.path.join('../test_data', subj_id, 'mri', 's2023-02-28_13-33-133958-00001-00224-1.nii' )

# Mesh to use for forward model in the simulations
multilayer_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'multilayer.11.ds.link_vector.fixed.gii')

# Load multilayer mesh and compute the number of vertices per layer
mesh = nib.load(multilayer_mesh_fname)
n_layers = 11
verts_per_surf = int(mesh.darrays[0].data.shape[0]/n_layers)

# Get name of each mesh that makes up the layers of the multilayer mesh - these will be used for the source 
# reconstruction
layer_fnames = get_surface_names(
    n_layers, 
    os.path.join('../test_data', subj_id, 'surf'), 
    'link_vector.fixed'
)

# %% [markdown]
# We're going to copy the data file to a temporary directory and direct all output there.

# %%
# Extract base name and path of data file
data_path, data_file_name = os.path.split(data_file)
data_base = os.path.splitext(data_file_name)[0]

# Where to put simulated data
tmp_dir = '/scratch/bonaiuto/simulated_data/model_comp_cverr'

# Copy data files to tmp directory
shutil.copy(
    os.path.join(data_path, f'{data_base}.mat'), 
    os.path.join(tmp_dir, f'{data_base}.mat')
)
shutil.copy(
    os.path.join(data_path, f'{data_base}.dat'), 
    os.path.join(tmp_dir, f'{data_base}.dat')
)

# Construct base file name for simulations
base_fname = os.path.join(tmp_dir, f'{data_base}.mat')

# %% [markdown]
# Invert the subject's data using the multilayer mesh. This step only has to be done once - this is just to compute the forward model that will be used in the simulations

# %%
# Patch size to use for inversion (in this case it matches the simulated patch size)
patch_size = 5
# Number of temporal modes to use for EBB inversion
n_temp_modes = 4

# Coregister data to multilayer mesh
coregister(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    multilayer_mesh_fname, 
    base_fname,
    spm_instance=spm
)

# Run inversion
[_,_] = invert_ebb(
    multilayer_mesh_fname, 
    base_fname, 
    n_layers, 
    patch_size=patch_size, 
    n_temp_modes=n_temp_modes,
    spm_instance=spm
)
# Out:
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
# Initialising batch system... done.
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 14:39:08 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 14:39:08 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           14:39:09 - 09/07/2024
# ========================================================================
# multilayer.11.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           14:40:14 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          14:40:15 - 09/07/2024
# computing surface normals
# 09-Jul-2024 14:40:19 - Done    'Head model specification'
# 09-Jul-2024 14:40:19 - Done
#
# Smoothing ../test_data/sub-104/surf/multilayer.11.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.33 times vertex spacing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using maximum of 274 spatial modes
#
#         SPM: spm_eeg_lgainmat                      14:40:21 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
# Starting parallel pool (parpool) using the 'local' profile ...
# Connected to the parallel pool (number of workers: 32).
#
# Preparing modes file  block 1 of 1 for 274 training and 0 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 14:44:02 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 14:44:02 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.8080    0.6261
#     0.8964    0.1712
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_multilayer.11.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 274 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 26.84 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.831238e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623467e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.274546e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.731314e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.008598e+04 [+4.62]
#   ReML Iteration 6                      :        ...4.837270e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.796261e+00 [+4.88]
#   ReML Iteration 8                      :        ...5.135344e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.581148e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    274
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.831238e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623467e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.274546e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.731314e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.008598e+04 [+4.62]
#   ReML Iteration 6                      :        ...4.837270e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.796261e+00 [+4.88]
#   ReML Iteration 8                      :        ...5.135344e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.581148e-03 [+5.12]
# Percent variance explained 99.82 (26.79)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 274
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [547162x1 double]
#             A: [274x274 double]
#            Ip: [1x512 double]
#             M: [547162x274 double]
#             J: {[547162x4 double]}
#             Y: [274x4 double]
#             L: [274x547162 double]
#            qC: [547162x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[274x274 double]}
#            Is: [1x547162 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x274 double]}
#            Nd: 547162
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -4.1391e+05
#            ID: 353.6925
#            R2: 99.8199
#            VE: 26.7884
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 274
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -4.1391e+05
#       PostMax: [547162x1 double]
#             A: [274x274 double]
#            Ip: [1x512 double]
#             M: [547162x274 double]
#             J: {[547162x4 double]}
#             Y: [274x4 double]
#             L: [274x547162 double]
#            qC: [547162x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[274x274 double]}
#            Is: [1x547162 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x274 double]}
#            Nd: 547162
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -4.1391e+05
#            ID: 353.6925
#            R2: 99.8199
#            VE: 26.7884
#
# 09-Jul-2024 14:49:46 - Done    'Source inversion, iterative'
# 09-Jul-2024 14:49:46 - Done

# %% [markdown]
# ## Simulating a signal on the pial surface
# We're going to simulate 1s of a 20Hz sine wave with a dipole moment of 10nAm

# %%
# Frequency of simulated sinusoid (Hz)
freq = 20
# Strength of simulated activity (nAm)
dipole_moment = 10
# Sampling rate (must match the data file)
s_rate = 600

# Generate 1s of a sine wave at a sampling rate of 600Hz (to match the data file)
time = np.linspace(0,1,s_rate+1)
sim_signal = np.sin(time*freq*2*np.pi).reshape(1,-1)

plt.plot(time,dipole_moment*sim_signal[0,:])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (nAm)')
# Out:
# Text(0, 0.5, 'Amplitude (nAm)')

# %% [markdown]
# We need to pick a location (mesh vertex) to simulate at

# %%
# Vertex to simulate activity at
sim_vertex=24588

pial_ds_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'pial.ds.link_vector.fixed.gii')
pial_ds_mesh = nib.load(pial_ds_mesh_fname)
pial_coord = pial_ds_mesh.darrays[0].data[sim_vertex,:]
pial_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'pial.gii')
pial_mesh = nib.load(pial_mesh_fname)
cam_view = [152, 28, 15,
            3.5, 26, 38.5,
            0, 0, 1]
plot = show_surface(
    pial_mesh, 
    opacity=1, 
    coords=pial_coord,
    coord_size=2,
    camera_view=cam_view
)
# Out:
# Output()

# %% [markdown]
# We'll simulate a 5mm patch of activity with -5 dB SNR at the sensor level. The desired level of SNR is achieved by adding white noise to the projected sensor signals

# %%
# Simulate at a vertex on the pial surface
pial_vertex = sim_vertex
prefix = f'sim_{sim_vertex}_pial_'

# Size of simulated patch of activity (mm)
sim_patch_size = 5
# SNR of simulated data (dB)
SNR = -5

# Generate simulated data
pial_sim_fname = run_current_density_simulation(
    base_fname, 
    prefix, 
    pial_vertex, 
    sim_signal, 
    dipole_moment, 
    sim_patch_size, 
    SNR,
    spm_instance=spm
)
# Out:
# Simulating data on MEG channels only
# Using closest mesh vertices to the specified coordinates
# Furthest distance from dipole location to mesh 0.00 mm
#
# ans =
#
#     'm'
#
# SIMULATING CURRENT DISTRIBUTIONS ON MESH
# Computing Gain Matrix:  - done
# Saving prior in directory /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo
# Using 1 iterations of 1 fixed patches
#
#  In last iteration...setting up patch 1 with  10.00 nAm , FWHM 5.00mm, mean moment density 518.23 pAm/mm2, peak momemnt density 1385.37 pAm/mm2
# Prior 1. Average Mean (over dist of FWHM from centre) moment density 518.23, sd 0.00 pAm/mm2
# Prior 1. Average Peak (max vertex) moment density 1385.37, sd 0.00 pAm/mm2
# Saving /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo/prior950096.mat
# Setting white noise to give sensor level SNR of -5B
# Assembling 1 prior components
# end assemble
#
#  Finish

# %% [markdown]
# ## Model comparison (pial - white matter)
# Now we can run model comparison between source models based on the pial and white matter surfaces using cross-validation error. For computing cross-validation error, we'll run 10 folds, leaving out 10% of the channels in each fold. We'll then look at the difference in cross-validation error between the two models (pial - white matter). This should be lower for the pial surface model because we simulated activity on the pial surface

# %%
# Number of cross validation folds
n_folds = 10
# Percentage of test channels in cross validation
ideal_pc_test = 10 # may not use this number as we need integer number of channels

# Run model comparison between the first layer (pial) and the last layer (white matter)
[_,cvErr] = model_comparison(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    [layer_fnames[0], layer_fnames[-1]], 
    pial_sim_fname, 
    patch_size=patch_size, 
    n_temp_modes=n_temp_modes, 
    n_folds=n_folds, 
    ideal_pc_test=ideal_pc_test,
    spm_instance=spm
)
    
# The difference in cross validation error after averaging over test channels and folds
# This value should be negative (less error for the pial layer model)
np.mean(np.mean(cvErr[0],axis=-1),axis=-1)-np.mean(np.mean(cvErr[1],axis=-1),axis=-1)
# Out:
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 14:55:12 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 14:55:12 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           14:55:27 - 09/07/2024
# ========================================================================
# pial.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           14:55:52 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          14:55:52 - 09/07/2024
# computing surface normals
# 09-Jul-2024 14:55:54 - Done    'Head model specification'
# 09-Jul-2024 14:55:54 - Done
#
# Smoothing ../test_data/sub-104/surf/pial.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.11 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      14:55:55 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 14:56:17 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 14:56:17 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24588_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.62 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.884211e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.771109e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.535619e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.075045e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.509590e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.037231e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.299201e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.152573e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.492562e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.884211e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.771109e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.535619e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.075045e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.509590e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.037231e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.299201e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.152573e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.492562e-04 [+5.12]
# Percent variance explained 99.99 (56.61)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8792e+05
#            ID: 553.7242
#            R2: 99.9867
#            VE: 56.6129
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8792e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8792e+05
#            ID: 553.7242
#            R2: 99.9867
#            VE: 56.6129
#
#
#  Cross val iteration 1 of 10, first two chans:175, 228..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.34 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.881055e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.766929e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.537526e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.097485e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.035178e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.230795e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.903727e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.050138e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.557878e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.881055e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.766929e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.537526e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.097485e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.035178e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.230795e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.903727e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.050138e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.557878e-04 [+5.12]
# Percent variance explained 99.99 (58.33)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8921e+05
#            ID: 578.4320
#            R2: 99.9862
#            VE: 58.3286
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8921e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8921e+05
#            ID: 578.4320
#            R2: 99.9862
#            VE: 58.3286
#
#
#  Cross val iteration 2 of 10, first two chans:13, 161..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.36 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.882950e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.767169e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.523935e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.046973e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.919544e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.469353e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.974383e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.276726e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.882950e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.767169e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.523935e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.046973e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.919544e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.469353e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.974383e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.276726e-03 [+5.00]
# Percent variance explained 99.99 (55.35)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8772e+05
#            ID: 560.7604
#            R2: 99.9856
#            VE: 55.3502
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8772e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8772e+05
#            ID: 560.7604
#            R2: 99.9856
#            VE: 55.3502
#
#
#  Cross val iteration 3 of 10, first two chans:218, 194..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.77 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.892788e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.790849e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.574461e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.141050e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.816167e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.573968e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.996000e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.052887e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.333269e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.892788e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.790849e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.574461e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.141050e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.816167e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.573968e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.996000e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.052887e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.333269e-03 [+5.12]
# Percent variance explained 99.99 (58.76)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8675e+05
#            ID: 567.4702
#            R2: 99.9851
#            VE: 58.7580
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8675e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8675e+05
#            ID: 567.4702
#            R2: 99.9851
#            VE: 58.7580
#
#
#  Cross val iteration 4 of 10, first two chans:230, 232..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.87 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.888822e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780811e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.550937e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.092405e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.407107e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.406875e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.752787e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.571466e-02 [+5.00]
#   ReML Iteration 9                      :        ...8.486257e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.888822e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780811e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.550937e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.092405e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.407107e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.406875e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.752787e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.571466e-02 [+5.00]
#   ReML Iteration 9                      :        ...8.486257e-04 [+5.12]
# Percent variance explained 99.99 (56.86)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8695e+05
#            ID: 556.9084
#            R2: 99.9854
#            VE: 56.8575
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8695e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8695e+05
#            ID: 556.9084
#            R2: 99.9854
#            VE: 56.8575
#
#
#  Cross val iteration 5 of 10, first two chans:111, 193..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.40 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.893818e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.793742e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.579366e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.143696e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.241250e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.574772e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.843481e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.881567e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.177489e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.893818e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.793742e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.579366e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.143696e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.241250e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.574772e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.843481e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.881567e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.177489e-03 [+5.12]
# Percent variance explained 99.98 (58.39)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8584e+05
#            ID: 580.0528
#            R2: 99.9840
#            VE: 58.3908
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8584e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8584e+05
#            ID: 580.0528
#            R2: 99.9840
#            VE: 58.3908
#
#
#  Cross val iteration 6 of 10, first two chans:169, 273..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.21 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891936e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.789370e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.574158e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.147310e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.194050e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.461896e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.709902e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.011672e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.424097e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891936e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.789370e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.574158e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.147310e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.194050e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.461896e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.709902e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.011672e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.424097e-03 [+5.12]
# Percent variance explained 99.99 (59.20)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8720e+05
#            ID: 585.6893
#            R2: 99.9867
#            VE: 59.1975
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8720e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8720e+05
#            ID: 585.6893
#            R2: 99.9867
#            VE: 59.1975
#
#
#  Cross val iteration 7 of 10, first two chans:80, 46..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.01 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.883440e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.768884e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.529451e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.060591e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.414743e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.178275e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.274128e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.110984e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.156763e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.883440e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.768884e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.529451e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.060591e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.414743e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.178275e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.274128e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.110984e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.156763e-04 [+5.12]
# Percent variance explained 99.99 (56.00)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8787e+05
#            ID: 569.2330
#            R2: 99.9864
#            VE: 55.9984
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8787e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8787e+05
#            ID: 569.2330
#            R2: 99.9864
#            VE: 55.9984
#
#
#  Cross val iteration 8 of 10, first two chans:198, 9..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.02 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.890377e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785316e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.563327e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.121151e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.635046e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.989702e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.515076e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.599883e-02 [+5.00]
#   ReML Iteration 9                      :        ...9.682487e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.890377e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785316e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.563327e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.121151e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.635046e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.989702e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.515076e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.599883e-02 [+5.00]
#   ReML Iteration 9                      :        ...9.682487e-04 [+5.12]
# Percent variance explained 99.99 (58.02)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8691e+05
#            ID: 566.5537
#            R2: 99.9861
#            VE: 58.0152
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8691e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8691e+05
#            ID: 566.5537
#            R2: 99.9861
#            VE: 58.0152
#
#
#  Cross val iteration 9 of 10, first two chans:52, 108..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.61 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.887452e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780759e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.562762e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.138262e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.788696e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.786767e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.439652e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.864793e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.366919e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.887452e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780759e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.562762e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.138262e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.788696e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.786767e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.439652e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.864793e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.366919e-03 [+5.12]
# Percent variance explained 99.99 (59.61)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8858e+05
#            ID: 594.2887
#            R2: 99.9879
#            VE: 59.6073
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8858e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8858e+05
#            ID: 594.2887
#            R2: 99.9879
#            VE: 59.6073
#
#
#  Cross val iteration 10 of 10, first two chans:272, 186..
# Running cross val..09-Jul-2024 14:58:50 - Done    'Source inversion, iterative'
# 09-Jul-2024 14:58:50 - Done
#
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 14:58:52 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 14:58:52 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           14:58:53 - 09/07/2024
# ========================================================================
# white.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           14:59:18 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          14:59:18 - 09/07/2024
# computing surface normals
# 09-Jul-2024 14:59:20 - Done    'Head model specification'
# 09-Jul-2024 14:59:20 - Done
#
# Smoothing ../test_data/sub-104/surf/white.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.58 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      14:59:20 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# ...
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0230e+05
#            ID: 571.6695
#            R2: 99.9664
#            VE: 57.5360
#
#
#  Cross val iteration 6 of 10, first two chans:101, 127..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.37 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.765824e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.590623e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.324520e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.869548e+04 [+4.50]
#   ReML Iteration 5                      :        ...8.045076e+01 [+4.62]
#   ReML Iteration 6                      :        ...7.135032e-02 [+4.75]
#   ReML Iteration 7                      :        ...8.375983e-05 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.765824e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.590623e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.324520e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.869548e+04 [+4.50]
#   ReML Iteration 5                      :        ...8.045076e+01 [+4.62]
#   ReML Iteration 6                      :        ...7.135032e-02 [+4.75]
#   ReML Iteration 7                      :        ...8.375983e-05 [+4.88]
# Percent variance explained 99.97 (57.36)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.9984e+05
#            ID: 560.7110
#            R2: 99.9716
#            VE: 57.3551
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.9984e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.9984e+05
#            ID: 560.7110
#            R2: 99.9716
#            VE: 57.3551
#  Cross val iteration 7 of 10, first two chans:187, 179..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.70 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.731638e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.557928e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.300784e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.869087e+04 [+4.50]
#   ReML Iteration 5                      :        ...8.512809e+01 [+4.62]
#   ReML Iteration 6                      :        ...6.470538e-03 [+4.75]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.731638e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.557928e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.300784e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.869087e+04 [+4.50]
#   ReML Iteration 5                      :        ...8.512809e+01 [+4.62]
#   ReML Iteration 6                      :        ...6.470538e-03 [+4.75]
# Percent variance explained 99.97 (58.68)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0177e+05
#            ID: 574.7204
#            R2: 99.9715
#            VE: 58.6802
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0177e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0177e+05
#            ID: 574.7204
#            R2: 99.9715
#            VE: 58.6802
#
#
#  Cross val iteration 8 of 10, first two chans:8, 154..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.85 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.691763e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.518278e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.265897e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.836855e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.212979e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.563670e-02 [+4.75]
#   ReML Iteration 7                      :        ...2.699161e-05 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.691763e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.518278e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.265897e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.836855e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.212979e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.563670e-02 [+4.75]
#   ReML Iteration 7                      :        ...2.699161e-05 [+4.88]
# Percent variance explained 99.97 (58.83)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0424e+05
#            ID: 579.3038
#            R2: 99.9658
#            VE: 58.8322
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0424e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0424e+05
#            ID: 579.3038
#            R2: 99.9658
#            VE: 58.8322
#
#
#  Cross val iteration 9 of 10, first two chans:192, 194..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.56 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.708524e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.511588e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.220495e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.729311e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.009251e+04 [+4.62]
#   ReML Iteration 6                      :        ...1.664898e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.756017e-04 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.708524e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.511588e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.220495e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.729311e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.009251e+04 [+4.62]
#   ReML Iteration 6                      :        ...1.664898e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.756017e-04 [+4.88]
# Percent variance explained 99.96 (53.54)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0261e+05
#            ID: 543.4922
#            R2: 99.9645
#            VE: 53.5448
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0261e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0261e+05
#            ID: 543.4922
#            R2: 99.9645
#            VE: 53.5448
#
#
#  Cross val iteration 10 of 10, first two chans:188, 235..
# Running cross val..09-Jul-2024 15:02:15 - Done    'Source inversion, iterative'
# 09-Jul-2024 15:02:15 - Done
# -2.8548188001182098

# %% [markdown]
# ## White matter surface simulation with pial - white matter model comparison
# Let's simulate the same pattern of activity, in the same location, but on the white matter surface. This time, model comparison should yield lower cross-validation error for the white matter surface.

# %%
# Simulate at the corresponding vertex on the white matter surface
white_vertex = (n_layers-1)*verts_per_surf+sim_vertex
prefix = f'sim_{sim_vertex}_white_'

# Generate simulated data
white_sim_fname = run_current_density_simulation(
    base_fname, 
    prefix, 
    white_vertex, 
    sim_signal, 
    dipole_moment, 
    sim_patch_size, 
    SNR,
    spm_instance=spm
) 

# Run model comparison between the first layer (pial) and the last layer (white matter)
[_,cvErr] = model_comparison(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    [layer_fnames[0], layer_fnames[-1]], 
    white_sim_fname, 
    patch_size=patch_size, 
    n_temp_modes=n_temp_modes, 
    n_folds=n_folds, 
    ideal_pc_test=ideal_pc_test,
    spm_instance=spm
)

# The difference in cross validation error after averaging over test channels and folds
# This value should be positive (less error for the white matter layer model)
np.mean(np.mean(cvErr[0],axis=-1),axis=-1)-np.mean(np.mean(cvErr[1],axis=-1),axis=-1)
# Out:
# Simulating data on MEG channels only
# Using closest mesh vertices to the specified coordinates
# Furthest distance from dipole location to mesh 0.00 mm
#
# ans =
#
#     'm'
#
# SIMULATING CURRENT DISTRIBUTIONS ON MESH
# Computing Gain Matrix:  - done
# Saving prior in directory /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo
# Using 1 iterations of 1 fixed patches
#
#  In last iteration...setting up patch 1 with  10.00 nAm , FWHM 5.00mm, mean moment density 512.65 pAm/mm2, peak momemnt density 1482.08 pAm/mm2
# Prior 1. Average Mean (over dist of FWHM from centre) moment density 512.65, sd 0.00 pAm/mm2
# Prior 1. Average Peak (max vertex) moment density 1482.08, sd 0.00 pAm/mm2
# Saving /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo/prior634205.mat
# Setting white noise to give sensor level SNR of -5B
# Assembling 1 prior components
# end assemble
#
#  Finish
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:07:32 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:07:32 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           15:07:47 - 09/07/2024
# ========================================================================
# pial.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           15:08:12 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          15:08:12 - 09/07/2024
# computing surface normals
# 09-Jul-2024 15:08:14 - Done    'Head model specification'
# 09-Jul-2024 15:08:14 - Done
#
# Smoothing ../test_data/sub-104/surf/pial.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.11 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      15:08:14 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:08:37 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:08:37 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24588_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.86 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.769995e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.613600e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.360674e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.892509e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.583585e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.346929e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.852750e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.970215e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.769995e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.613600e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.360674e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.892509e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.583585e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.346929e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.852750e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.970215e-04 [+5.00]
# Percent variance explained 99.98 (55.85)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8335e+05
#            ID: 442.4502
#            R2: 99.9844
#            VE: 55.8545
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8335e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8335e+05
#            ID: 442.4502
#            R2: 99.9844
#            VE: 55.8545
#  Cross val iteration 1 of 10, first two chans:213, 205..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.31 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.768904e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.609384e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.352384e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.878912e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.570080e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.311770e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.802517e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.880050e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.768904e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.609384e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.352384e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.878912e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.570080e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.311770e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.802517e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.880050e-04 [+5.00]
# Percent variance explained 99.98 (55.31)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8331e+05
#            ID: 435.8714
#            R2: 99.9839
#            VE: 55.3051
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8331e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8331e+05
#            ID: 435.8714
#            R2: 99.9839
#            VE: 55.3051
#
#
#  Cross val iteration 2 of 10, first two chans:162, 177..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.86 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.787615e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.631841e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.386396e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.941584e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.688602e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.740373e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.431773e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.935798e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.787615e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.631841e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.386396e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.941584e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.688602e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.740373e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.431773e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.935798e-04 [+5.00]
# Percent variance explained 99.98 (57.85)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8288e+05
#            ID: 466.3159
#            R2: 99.9835
#            VE: 57.8544
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8288e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8288e+05
#            ID: 466.3159
#            R2: 99.9835
#            VE: 57.8544
#
#
#  Cross val iteration 3 of 10, first two chans:141, 142..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.02 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.809966e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.658940e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.409861e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.953945e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.014327e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.563483e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.773730e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.736459e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.809966e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.658940e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.409861e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.953945e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.014327e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.563483e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.773730e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.736459e-04 [+5.00]
# Percent variance explained 99.98 (57.01)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8107e+05
#            ID: 450.6457
#            R2: 99.9838
#            VE: 57.0117
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8107e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8107e+05
#            ID: 450.6457
#            R2: 99.9838
#            VE: 57.0117
#
#
#  Cross val iteration 4 of 10, first two chans:233, 237..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.29 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.782419e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.626470e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.379873e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.930370e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.100552e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.005896e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.956248e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.263030e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.782419e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.626470e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.379873e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.930370e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.100552e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.005896e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.956248e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.263030e-04 [+5.00]
# Percent variance explained 99.99 (57.28)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8306e+05
#            ID: 455.7355
#            R2: 99.9855
#            VE: 57.2789
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8306e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8306e+05
#            ID: 455.7355
#            R2: 99.9855
#            VE: 57.2789
#
#
#  Cross val iteration 5 of 10, first two chans:80, 20..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.06 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.787466e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.626131e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.363965e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.884986e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.966920e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.328525e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.469722e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.932899e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.787466e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.626131e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.363965e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.884986e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.966920e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.328525e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.469722e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.932899e-04 [+5.00]
# Percent variance explained 99.98 (55.05)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8221e+05
#            ID: 440.8605
#            R2: 99.9827
#            VE: 55.0477
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8221e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8221e+05
#            ID: 440.8605
#            R2: 99.9827
#            VE: 55.0477
#
#
#  Cross val iteration 6 of 10, first two chans:243, 100..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.18 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.732873e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.565276e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.294325e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.796432e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.992962e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.021583e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.331662e-03 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.732873e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.565276e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.294325e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.796432e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.992962e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.021583e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.331662e-03 [+4.88]
# Percent variance explained 99.98 (53.17)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8506e+05
#            ID: 431.3924
#            R2: 99.9814
#            VE: 53.1730
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8506e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8506e+05
#            ID: 431.3924
#            R2: 99.9814
#            VE: 53.1730
#
#
#  Cross val iteration 7 of 10, first two chans:208, 186..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.24 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.767031e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.605127e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.345758e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.870972e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.185985e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.078236e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.331865e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.898543e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.767031e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.605127e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.345758e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.870972e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.185985e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.078236e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.331865e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.898543e-04 [+5.00]
# Percent variance explained 99.98 (55.23)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8353e+05
#            ID: 437.5292
#            R2: 99.9836
#            VE: 55.2303
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8353e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8353e+05
#            ID: 437.5292
#            R2: 99.9836
#            VE: 55.2303
#
#
#  Cross val iteration 8 of 10, first two chans:7, 153..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.10 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.793695e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.639893e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.387766e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.920673e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.831994e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.643874e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.605612e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.869444e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.793695e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.639893e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.387766e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.920673e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.831994e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.643874e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.605612e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.869444e-04 [+5.00]
# Percent variance explained 99.98 (56.09)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8177e+05
#            ID: 440.5821
#            R2: 99.9843
#            VE: 56.0926
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8177e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8177e+05
#            ID: 440.5821
#            R2: 99.9843
#            VE: 56.0926
#
#
#  Cross val iteration 9 of 10, first two chans:191, 193..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.92 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.828838e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.677723e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.410552e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.914200e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.915458e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.448139e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.577872e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.992499e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.828838e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.677723e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.410552e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.914200e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.915458e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.448139e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.577872e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.992499e-04 [+5.00]
# Percent variance explained 99.98 (53.91)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7906e+05
#            ID: 431.0137
#            R2: 99.9849
#            VE: 53.9073
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7906e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7906e+05
#            ID: 431.0137
#            R2: 99.9849
#            VE: 53.9073
#
#
#  Cross val iteration 10 of 10, first two chans:187, 234..
# Running cross val..09-Jul-2024 15:11:10 - Done    'Source inversion, iterative'
# 09-Jul-2024 15:11:10 - Done
#
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:11:11 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:11:11 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           15:11:13 - 09/07/2024
# ========================================================================
# white.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           15:11:42 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          15:11:43 - 09/07/2024
# computing surface normals
# 09-Jul-2024 15:11:44 - Done    'Head model specification'
# 09-Jul-2024 15:11:44 - Done
#
# Smoothing ../test_data/sub-104/surf/white.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.58 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      15:11:45 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:12:08 - Running job #1
# ...
#
#
#  Cross val iteration 6 of 10, first two chans:101, 127..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.28 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.859584e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.725895e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.470990e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.990696e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.371911e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.910357e+00 [+4.75]
#   ReML Iteration 7                      :        ...8.465346e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.367223e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.859584e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.725895e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.470990e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.990696e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.371911e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.910357e+00 [+4.75]
#   ReML Iteration 7                      :        ...8.465346e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.367223e-03 [+5.00]
# Percent variance explained 99.99 (55.27)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7636e+05
#            ID: 435.0229
#            R2: 99.9858
#            VE: 55.2672
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7636e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7636e+05
#            ID: 435.0229
#            R2: 99.9858
#            VE: 55.2672
#
#
#  Cross val iteration 7 of 10, first two chans:187, 179..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.89 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.851852e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.717461e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.472309e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.013701e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.360502e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.448742e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.951719e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.743209e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.851852e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.717461e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.472309e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.013701e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.360502e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.448742e+00 [+4.75]
#   ReML Iteration 7                      :        ...5.951719e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.743209e-03 [+5.00]
# Percent variance explained 99.99 (56.88)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7720e+05
#            ID: 446.1242
#            R2: 99.9861
#            VE: 56.8816
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7720e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7720e+05
#            ID: 446.1242
#            R2: 99.9861
#            VE: 56.8816
#
#
#  Cross val iteration 8 of 10, first two chans:8, 154..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.97 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.806942e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.657822e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.411571e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.957251e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.429605e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.121846e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.893121e-02 [+4.88]
#   ReML Iteration 8                      :        ...3.658128e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.806942e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.657822e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.411571e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.957251e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.429605e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.121846e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.893121e-02 [+4.88]
#   ReML Iteration 8                      :        ...3.658128e-04 [+5.00]
# Percent variance explained 99.98 (56.96)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8074e+05
#            ID: 449.2220
#            R2: 99.9846
#            VE: 56.9635
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8074e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8074e+05
#            ID: 449.2220
#            R2: 99.9846
#            VE: 56.9635
#
#
#  Cross val iteration 9 of 10, first two chans:192, 194..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 52.16 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.813453e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.653515e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.373578e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.855653e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.062531e+04 [+4.62]
#   ReML Iteration 6                      :        ...8.134773e+01 [+4.75]
#   ReML Iteration 7                      :        ...4.903763e-03 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.813453e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.653515e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.373578e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.855653e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.062531e+04 [+4.62]
#   ReML Iteration 6                      :        ...8.134773e+01 [+4.75]
#   ReML Iteration 7                      :        ...4.903763e-03 [+4.88]
# Percent variance explained 99.98 (52.15)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7987e+05
#            ID: 423.9072
#            R2: 99.9831
#            VE: 52.1485
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7987e+05
#       PostMax: [49742x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49742x247 double]
#             J: {[49742x4 double]}
#             Y: [247x4 double]
#             L: [247x49742 double]
#            qC: [49742x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49742 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49742
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7987e+05
#            ID: 423.9072
#            R2: 99.9831
#            VE: 52.1485
#
#
#  Cross val iteration 10 of 10, first two chans:188, 235..
# Running cross val..09-Jul-2024 15:14:41 - Done    'Source inversion, iterative'
# 09-Jul-2024 15:14:41 - Done
# 0.5128407127130075

# %% [markdown]
# ## Simulation in each layer with model comparison across layers
# That was model comparison with two candidate models: one based on the white matter surface, and one on the pial. Let's now simulate on each layer, and for each simulation, run model comparison across all layers. We'll turn off SPM visualization here.

# %%
# Now simulate at the corresponding vertex on each layer, and for each simulation, run model comparison across
# all layers
all_layerCvErr = []

for l in range(n_layers):
    print(f'Simulating in layer {l}')
    l_vertex = l*verts_per_surf+sim_vertex
    prefix = f'sim_{sim_vertex}_{l}_'

    l_sim_fname = run_current_density_simulation(
        base_fname, 
        prefix, 
        l_vertex, 
        sim_signal, 
        dipole_moment, 
        sim_patch_size, 
        SNR,
        spm_instance=spm
    ) 

    [_,layerCvErr] = model_comparison(
        nas, 
        lpa, 
        rpa, 
        mri_fname, 
        layer_fnames, 
        l_sim_fname, 
        patch_size=patch_size, 
        n_temp_modes=n_temp_modes, 
        n_folds=n_folds,
        ideal_pc_test=ideal_pc_test, 
        viz=False,
        spm_instance=spm
    )
    all_layerCvErr.append(layerCvErr)    
all_layerCvErr = np.array(all_layerCvErr)

# Average over test channels and folds
all_layerCvErr = np.mean(np.mean(all_layerCvErr, axis=-1), axis=-1)
# Out:
# Simulating in layer 0
# Simulating data on MEG channels only
# Using closest mesh vertices to the specified coordinates
# Furthest distance from dipole location to mesh 0.00 mm
#
# ans =
#
#     'm'
#
# SIMULATING CURRENT DISTRIBUTIONS ON MESH
# Computing Gain Matrix:  - done
# Saving prior in directory /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo
# Using 1 iterations of 1 fixed patches
#
#  In last iteration...setting up patch 1 with  10.00 nAm , FWHM 5.00mm, mean moment density 518.23 pAm/mm2, peak momemnt density 1385.37 pAm/mm2
# Prior 1. Average Mean (over dist of FWHM from centre) moment density 518.23, sd 0.00 pAm/mm2
# Prior 1. Average Peak (max vertex) moment density 1385.37, sd 0.00 pAm/mm2
# Saving /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo/prior634205.mat
# Setting white noise to give sensor level SNR of -5B
# Assembling 1 prior components
# end assemble
#
#  Finish
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:19:59 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:19:59 - Running 'Head model specification'
# pial.ds.link_vector.fixed
#
# SPM: spm_eeg_inv_forward                           15:20:37 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          15:20:38 - 09/07/2024
# 09-Jul-2024 15:20:39 - Done    'Head model specification'
# 09-Jul-2024 15:20:39 - Done
#
# Smoothing ../test_data/sub-104/surf/pial.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.11 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      15:20:39 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:21:02 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:21:02 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.60 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.882714e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.768943e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.536181e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.086494e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.746809e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.046672e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.035606e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.040802e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.085891e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.882714e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.768943e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.536181e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.086494e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.746809e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.046672e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.035606e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.040802e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.085891e-04 [+5.12]
# Percent variance explained 99.99 (57.59)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 1 of 10, first two chans:213, 205..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.25 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.894477e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.795657e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.579153e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.129015e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.324504e+02 [+4.62]
#   ReML Iteration 6                      :        ...8.032694e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.939713e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.586665e-02 [+5.00]
#   ReML Iteration 9                      :        ...7.994868e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.894477e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.795657e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.579153e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.129015e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.324504e+02 [+4.62]
#   ReML Iteration 6                      :        ...8.032694e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.939713e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.586665e-02 [+5.00]
#   ReML Iteration 9                      :        ...7.994868e-04 [+5.12]
# Percent variance explained 99.98 (57.24)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 2 of 10, first two chans:162, 177..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.72 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.896433e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.799848e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.593694e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.175405e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.527519e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.159846e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.934639e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.693471e-02 [+5.00]
#   ReML Iteration 9                      :        ...3.281341e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.896433e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.799848e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.593694e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.175405e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.527519e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.159846e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.934639e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.693471e-02 [+5.00]
#   ReML Iteration 9                      :        ...3.281341e-03 [+5.12]
# Percent variance explained 99.99 (59.71)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 3 of 10, first two chans:141, 142..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.88 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.890253e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785060e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.565038e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.132288e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.631535e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.329343e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.159093e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.322683e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.624174e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.890253e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785060e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.565038e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.132288e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.631535e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.329343e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.159093e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.322683e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.624174e-03 [+5.12]
# Percent variance explained 99.99 (58.87)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 4 of 10, first two chans:233, 237..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.22 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.890285e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785534e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.567190e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.138251e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.671067e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.032970e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.987801e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.183612e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.520255e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.890285e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.785534e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.567190e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.138251e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.671067e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.032970e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.987801e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.183612e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.520255e-03 [+5.12]
# Percent variance explained 99.99 (59.21)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 5 of 10, first two chans:80, 20..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.91 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.887458e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.777781e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.546293e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.088823e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.385725e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.698783e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.356247e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.270829e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.512426e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.887458e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.777781e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.546293e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.088823e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.385725e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.698783e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.356247e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.270829e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.512426e-04 [+5.12]
# Percent variance explained 99.99 (56.90)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 6 of 10, first two chans:243, 100..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 54.39 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.867961e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.737613e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.477981e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.985534e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.555897e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.299773e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.080481e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.006910e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.867961e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.737613e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.477981e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.985534e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.555897e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.299773e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.080481e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.006910e-03 [+5.00]
# Percent variance explained 99.99 (54.38)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 7 of 10, first two chans:208, 186..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.05 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891907e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.788103e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564708e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.112261e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.328796e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.038536e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.259043e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.041052e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.202487e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891907e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.788103e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564708e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.112261e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.328796e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.038536e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.259043e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.041052e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.202487e-03 [+5.12]
# Percent variance explained 99.99 (57.04)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 8 of 10, first two chans:7, 153..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.65 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.886388e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.776568e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.547980e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.099349e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.624787e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.596588e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.372831e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.298298e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.758585e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.886388e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.776568e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.547980e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.099349e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.624787e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.596588e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.372831e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.298298e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.758585e-04 [+5.12]
# Percent variance explained 99.99 (57.64)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 9 of 10, first two chans:191, 193..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.00 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891842e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.789849e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564677e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.095497e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.888958e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.112994e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.150570e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.147645e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891842e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.789849e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564677e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.095497e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.888958e+02 [+4.62]
#   ReML Iteration 6                      :        ...7.112994e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.150570e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.147645e-03 [+5.00]
# Percent variance explained 99.98 (55.98)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 10 of 10, first two chans:187, 234..
# Running cross val..09-Jul-2024 15:23:30 - Done    'Source inversion, iterative'
# 09-Jul-2024 15:23:30 - Done
#
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:23:31 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:23:31 - Running 'Head model specification'
# 0.900.ds.link_vector.fixed
#
# SPM: spm_eeg_inv_forward                           15:23:56 - 09/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          15:23:57 - 09/07/2024
# 09-Jul-2024 15:23:58 - Done    'Head model specification'
# 09-Jul-2024 15:23:58 - Done
#
# Smoothing ../test_data/sub-104/surf/0.900.ds.link_vector.fixed.gii
# FWHM of 5.00 is approx 3.15 times vertex spacing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      15:23:58 - 09/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st2/spm_standalo/lameg/matlab/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 09-Jul-2024 15:24:21 - Running job #1
# ------------------------------------------------------------------------
# 09-Jul-2024 15:24:21 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24588_0_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.09 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.881074e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.766647e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.535701e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.091797e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.011479e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.901654e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.808961e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.017664e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.500629e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.881074e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.766647e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.535701e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.091797e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.011479e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.901654e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.808961e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.017664e-02 [+5.00]
#   ReML Iteration 9                      :        ...5.500629e-04 [+5.12]
# Percent variance explained 99.99 (58.08)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 1 of 10, first two chans:214, 206..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.62 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.875965e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.756685e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.520339e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.070667e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.709951e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.939731e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.536722e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.353648e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.875965e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.756685e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.520339e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.070667e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.709951e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.939731e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.536722e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.353648e-03 [+5.00]
# Percent variance explained 99.99 (57.62)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 2 of 10, first two chans:163, 178..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.62 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.867956e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.746006e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.518032e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.092416e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.864015e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.479454e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.301800e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.820061e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.867956e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.746006e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.518032e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.092416e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.864015e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.479454e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.301800e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.820061e-03 [+5.00]
# Percent variance explained 99.99 (59.61)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 3 of 10, first two chans:142, 143..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 54.77 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.866268e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.735457e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.477778e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.990017e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.656708e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.874460e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.077970e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.173633e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.866268e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.735457e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.477778e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.990017e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.656708e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.874460e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.077970e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.173633e-03 [+5.00]
# Percent variance explained 99.99 (54.76)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 4 of 10, first two chans:234, 238..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.55 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.874279e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755166e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.523431e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.084806e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.132076e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.882697e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.362856e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.550079e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.874279e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755166e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.523431e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.084806e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.132076e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.882697e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.362856e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.550079e-03 [+5.00]
# Percent variance explained 99.99 (58.54)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 5 of 10, first two chans:81, 21..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.51 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.878940e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.761488e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.524950e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.072913e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.489167e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.155953e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.552697e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.210905e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.878940e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.761488e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.524950e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.072913e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.489167e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.155953e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.552697e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.210905e-03 [+5.00]
# Percent variance explained 99.99 (57.50)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 6 of 10, first two chans:101, 127..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.33 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.875783e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755679e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.516757e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.062035e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.730994e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.207819e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.617585e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.693660e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.875783e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755679e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.516757e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.062035e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.730994e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.207819e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.617585e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.693660e-03 [+5.00]
# Percent variance explained 99.99 (57.32)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 7 of 10, first two chans:187, 179..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.65 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.887887e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780643e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.558551e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.122940e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.142708e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.710610e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.523349e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.669468e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.054050e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.887887e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.780643e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.558551e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.122940e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.142708e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.710610e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.523349e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.669468e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.054050e-03 [+5.12]
# Percent variance explained 99.99 (58.64)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 8 of 10, first two chans:8, 154..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_0.900.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.81 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.874458e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755375e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.524405e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.089610e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.097443e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.059325e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.367585e-01 [+4.88]
#   ReML Iteration 8                      :        ...7.217155e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.874458e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.755375e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.524405e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.089610e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.097443e+02 [+4.62]
# ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.78 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.870363e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.747723e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.511381e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.064969e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.024390e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.803395e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.861871e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.149506e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.870363e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.747723e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.511381e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.064969e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.024390e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.803395e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.861871e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.149506e-03 [+5.00]
# Percent variance explained 99.99 (57.78)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 3 of 10, first two chans:142, 143..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 52.80 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.869234e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.738054e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.470935e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.959258e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.154356e+04 [+4.62]
#   ReML Iteration 6                      :        ...1.169760e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.777278e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.946065e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.869234e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.738054e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.470935e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.959258e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.154356e+04 [+4.62]
#   ReML Iteration 6                      :        ...1.169760e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.777278e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.946065e-04 [+5.00]
# Percent variance explained 99.99 (52.80)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 4 of 10, first two chans:234, 238..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.64 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.831562e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.685815e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.434681e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.974355e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.565625e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.640346e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.842580e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.829114e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.831562e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.685815e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.434681e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.974355e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.565625e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.640346e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.842580e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.829114e-04 [+5.00]
# Percent variance explained 99.98 (56.63)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 5 of 10, first two chans:81, 21..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.90 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.848423e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.709035e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.455008e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.983579e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.826497e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.352993e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.526247e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.065167e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.848423e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.709035e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.455008e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.983579e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.826497e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.352993e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.526247e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.065167e-03 [+5.00]
# Percent variance explained 99.99 (55.89)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 6 of 10, first two chans:101, 127..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.30 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.839535e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.695768e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.439424e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.963844e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.999583e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.768467e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.883585e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.075324e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.839535e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.695768e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.439424e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.963844e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.999583e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.768467e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.883585e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.075324e-03 [+5.00]
# Percent variance explained 99.99 (55.29)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 7 of 10, first two chans:187, 179..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.93 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.856421e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.723674e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.478040e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.019530e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.496815e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.454916e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.397567e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.000001e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.856421e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.723674e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.478040e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.019530e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.496815e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.454916e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.397567e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.000001e-03 [+5.00]
# Percent variance explained 99.99 (56.92)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 8 of 10, first two chans:8, 154..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.98 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.811171e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.661047e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.413942e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.961018e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.062338e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.295064e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.683438e-02 [+4.88]
#   ReML Iteration 8                      :        ...6.346596e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.811171e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.661047e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.413942e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.961018e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.062338e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.295064e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.683438e-02 [+4.88]
#   ReML Iteration 8                      :        ...6.346596e-04 [+5.00]
# Percent variance explained 99.99 (56.97)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 9 of 10, first two chans:192, 194..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.2741    0.2186
#     0.4461    0.7577
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 52.18 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.756962e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.592862e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.316847e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.805536e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.679964e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.126604e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.753040e-03 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.756962e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.592862e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.316847e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.805536e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.679964e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.126604e+00 [+4.75]
#   ReML Iteration 7                      :        ...4.753040e-03 [+4.88]
# Percent variance explained 99.98 (52.17)
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#
#  Cross val iteration 10 of 10, first two chans:188, 235..
# Running cross val..09-Jul-2024 22:59:09 - Done    'Source inversion, iterative'
# 09-Jul-2024 22:59:09 - Done

# %% [markdown]
# For each simulation, we can plot the cross-validation error for all models relative to the worst model. The layer model with the lowest cross-validation error should correspond to the layer that the activity was simulated in.

# %%
col_r = plt.cm.cool(np.linspace(0,1, num=n_layers))
plt.figure(figsize=(10,4))

# For each simulation, plot the CV error of each layer model relative to that of the worst
# model for that simulation
plt.subplot(1,2,1)
for l in range(n_layers):
    layerCvErr=all_layerCvErr[l,:]
    plt.plot(layerCvErr, label=f'{l}', color=col_r[l,:])
plt.legend()
plt.xlabel('Eval layer')
plt.ylabel('CVErr')

# For each simulation, find which layer model had the lowest CV error
plt.subplot(1,2,2)
peaks=[]
for l in range(n_layers):
    layerCvErr=all_layerCvErr[l,:]
    pk=np.argmin(layerCvErr)
    peaks.append(pk)
plt.plot(peaks)
plt.xlim([-0.5,10.5])
plt.ylim([-0.5,10.5])
plt.plot([0,10],[0,10],'k--')
plt.xlabel('Sim layer')
plt.ylabel('Min CVErr')
plt.tight_layout()

# %%
spm.terminate()

# Delete simulation files

# Iterate over all items in the directory
for item in os.listdir(tmp_dir):
    item_path = os.path.join(tmp_dir, item)

    # Check if it's a file or a directory
    if os.path.isfile(item_path):
        # Delete the file
        os.remove(item_path)
    elif os.path.isdir(item_path):
        # Recursively delete the directory
        shutil.rmtree(item_path)
