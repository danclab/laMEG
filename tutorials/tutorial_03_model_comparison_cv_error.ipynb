# %% [markdown]
# # Laminar model comparison using cross-validation error

# %% [markdown]
# This tutorial demonstrates how to perform laminar inference using model comparison based on cross-validation error as a metric of model fit, described in [Bonaiuto et al., 2018, Non-invasive laminar inference with MEG: Comparison of methods and source inversion algorithms](https://doi.org/10.1016/j.neuroimage.2017.11.068). A 20Hz oscillation is simulated at a particular cortical location in various layers. Source reconstruction is performed using the Empirical Bayesian Beamformer on the simulated sensor data using forward models based on different layer meshes. These models are then compared using cross-validation error. Cross-validation error is computed by fitting the model N times, each time leaving out a certain percentage of the channels and seeing how well the resulting model can predict the signal in those channels
#
# ## Setting up the simulations
#
# Simulations are based on an existing dataset, which is used to define the sampling rate, number of trials, duration of each trial, and the channel layout.

# %%
import os
import shutil
import numpy as np
import nibabel as nib
from matplotlib import colors
import matplotlib.pyplot as plt

from lameg.invert import coregister, invert_ebb
from lameg.simulate import run_current_density_simulation
from lameg.laminar import model_comparison
from lameg.util import get_surface_names, get_fiducial_coords
from lameg.viz import show_surface
import spm_standalone

# Subject information for data to base the simulations on
subj_id = 'sub-104'
ses_id = 'ses-01'

# Fiducial coil coordinates
nas, lpa, rpa = get_fiducial_coords(subj_id, '../test_data/participants.tsv')

# Data file to base simulations on
data_file = os.path.join(
    '../test_data', 
    subj_id,
    'meg',
    ses_id, 
    'spm/spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo.mat'
)

spm = spm_standalone.initialize()

# %% [markdown]
# For source reconstructions, we need an MRI and a surface mesh. The simulations will be based on a forward model using the multilayer mesh, and the model comparison will use each layer mesh

# %%
# Native space MRI to use for coregistration
mri_fname = os.path.join('../test_data', subj_id, 'mri', 's2023-02-28_13-33-133958-00001-00224-1.nii' )

# Mesh to use for forward model in the simulations
multilayer_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'multilayer.11.ds.link_vector.fixed.gii')

# Load multilayer mesh and compute the number of vertices per layer
mesh = nib.load(multilayer_mesh_fname)
n_layers = 11
verts_per_surf = int(mesh.darrays[0].data.shape[0]/n_layers)

# Get name of each mesh that makes up the layers of the multilayer mesh - these will be used for the source 
# reconstruction
layer_fnames = get_surface_names(
    n_layers, 
    os.path.join('../test_data', subj_id, 'surf'), 
    'link_vector.fixed'
)

# %% [markdown]
# We're going to copy the data file to a temporary directory and direct all output there.

# %%
# Extract base name and path of data file
data_path, data_file_name = os.path.split(data_file)
data_base = os.path.splitext(data_file_name)[0]

# Where to put simulated data
tmp_dir = '/scratch/bonaiuto/simulated_data/model_comp_cverr'

# Copy data files to tmp directory
shutil.copy(
    os.path.join(data_path, f'{data_base}.mat'), 
    os.path.join(tmp_dir, f'{data_base}.mat')
)
shutil.copy(
    os.path.join(data_path, f'{data_base}.dat'), 
    os.path.join(tmp_dir, f'{data_base}.dat')
)

# Construct base file name for simulations
base_fname = os.path.join(tmp_dir, f'{data_base}.mat')

# %% [markdown]
# Invert the subject's data using the multilayer mesh. This step only has to be done once - this is just to compute the forward model that will be used in the simulations

# %%
# Patch size to use for inversion (in this case it matches the simulated patch size)
patch_size = 5
# Number of temporal modes to use for EBB inversion
n_temp_modes = 4

# Coregister data to multilayer mesh
coregister(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    multilayer_mesh_fname, 
    base_fname,
    spm_instance=spm
)

# Run inversion
[_,_] = invert_ebb(
    multilayer_mesh_fname, 
    base_fname, 
    n_layers, 
    patch_size=patch_size, 
    n_temp_modes=n_temp_modes,
    spm_instance=spm
)
# Out:
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
# Initialising batch system... done.
#
#
# ------------------------------------------------------------------------
# 25-Jul-2024 13:49:25 - Running job #1
# ------------------------------------------------------------------------
# 25-Jul-2024 13:49:26 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           13:49:26 - 25/07/2024
# ========================================================================
# multilayer.11.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           13:50:26 - 25/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          13:50:27 - 25/07/2024
# computing surface normals
# 25-Jul-2024 13:50:31 - Done    'Head model specification'
# 25-Jul-2024 13:50:31 - Done
#
# Smoothing ../test_data/sub-104/surf/multilayer.11.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '../test_data/sub-104/surf/FWHM5.00_multilayer.11.ds.link_vector.fixed.mat'
#
#
# Found smoothfile ../test_data/sub-104/surf/FWHM5.00_multilayer.11.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using maximum of 274 spatial modes
#
#         SPM: spm_eeg_lgainmat                      13:50:33 - 25/07/2024
#         ----------------------------------------------------------------
# computing surface normals
# Starting parallel pool (parpool) using the 'local' profile ...
# Preserving jobs with IDs: 16 because they contain crash dump files.
# You can use 'delete(myCluster.Jobs)' to remove all jobs created with profile local. To create 'myCluster' use 'myCluster = parcluster('local')'.
# Connected to the parallel pool (number of workers: 32).
#
# Preparing modes file  block 1 of 1 for 274 training and 0 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 25-Jul-2024 13:54:11 - Running job #1
# ------------------------------------------------------------------------
# 25-Jul-2024 13:54:11 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.4410    0.4444
#     0.9501    0.1151
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_multilayer.11.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 274 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 26.84 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.830843e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623140e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.274276e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.731309e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.008924e+04 [+4.62]
#   ReML Iteration 6                      :        ...4.823076e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.778626e+00 [+4.88]
#   ReML Iteration 8                      :        ...5.067012e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.554348e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    274
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.830843e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623140e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.274276e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.731309e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.008924e+04 [+4.62]
#   ReML Iteration 6                      :        ...4.823076e+02 [+4.75]
#   ReML Iteration 7                      :        ...1.778626e+00 [+4.88]
#   ReML Iteration 8                      :        ...5.067012e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.554348e-03 [+5.12]
# Percent variance explained 99.82 (26.79)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 274
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [547063x1 double]
#             A: [274x274 double]
#            Ip: [1x512 double]
#             M: [547063x274 double]
#             J: {[547063x4 double]}
#             Y: [274x4 double]
#             L: [274x547063 double]
#            qC: [547063x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[274x274 double]}
#            Is: [1x547063 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x274 double]}
#            Nd: 547063
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -4.1392e+05
#            ID: 353.6925
#            R2: 99.8198
#            VE: 26.7884
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 274
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -4.1392e+05
#       PostMax: [547063x1 double]
#             A: [274x274 double]
#            Ip: [1x512 double]
#             M: [547063x274 double]
#             J: {[547063x4 double]}
#             Y: [274x4 double]
#             L: [274x547063 double]
#            qC: [547063x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[274x274 double]}
#            Is: [1x547063 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x274 double]}
#            Nd: 547063
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -4.1392e+05
#            ID: 353.6925
#            R2: 99.8198
#            VE: 26.7884
#
# 25-Jul-2024 13:59:43 - Done    'Source inversion, iterative'
# 25-Jul-2024 13:59:43 - Done

# %% [markdown]
# ## Simulating a signal on the pial surface
# We're going to simulate 1s of a 20Hz sine wave with a dipole moment of 10nAm

# %%
# Frequency of simulated sinusoid (Hz)
freq = 20
# Strength of simulated activity (nAm)
dipole_moment = 10
# Sampling rate (must match the data file)
s_rate = 600

# Generate 1s of a sine wave at a sampling rate of 600Hz (to match the data file)
time = np.linspace(0,1,s_rate+1)
sim_signal = np.sin(time*freq*2*np.pi).reshape(1,-1)

plt.plot(time,dipole_moment*sim_signal[0,:])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (nAm)')
# Out:
# Text(0, 0.5, 'Amplitude (nAm)')

# %% [markdown]
# We need to pick a location (mesh vertex) to simulate at

# %%
# Vertex to simulate activity at
sim_vertex=24585

pial_ds_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'pial.ds.link_vector.fixed.gii')
pial_ds_mesh = nib.load(pial_ds_mesh_fname)
pial_coord = pial_ds_mesh.darrays[0].data[sim_vertex,:]
pial_mesh_fname = os.path.join('../test_data', subj_id, 'surf', 'pial.gii')
pial_mesh = nib.load(pial_mesh_fname)
cam_view = [152, 28, 15,
            3.5, 26, 38.5,
            0, 0, 1]
plot = show_surface(
    pial_mesh, 
    opacity=1, 
    coords=pial_coord,
    coord_size=2,
    camera_view=cam_view
)

# %% [markdown]
# We'll simulate a 5mm patch of activity with -5 dB SNR at the sensor level. The desired level of SNR is achieved by adding white noise to the projected sensor signals

# %%
# Simulate at a vertex on the pial surface
pial_vertex = sim_vertex
prefix = f'sim_{sim_vertex}_pial_'

# Size of simulated patch of activity (mm)
sim_patch_size = 5
# SNR of simulated data (dB)
SNR = -5

# Generate simulated data
pial_sim_fname = run_current_density_simulation(
    base_fname, 
    prefix, 
    pial_vertex, 
    sim_signal, 
    dipole_moment, 
    sim_patch_size, 
    SNR,
    spm_instance=spm
)
# Out:
# Simulating data on MEG channels only
# Using closest mesh vertices to the specified coordinates
# Furthest distance from dipole location to mesh 0.00 mm
#
# ans =
#
#     'm'
#
# SIMULATING CURRENT DISTRIBUTIONS ON MESH
# Computing Gain Matrix:  - done
# Saving prior in directory /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24585_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo
# Using 1 iterations of 1 fixed patches
#
#  In last iteration...setting up patch 1 with  10.00 nAm , FWHM 5.00mm, mean moment density 655.24 pAm/mm2, peak momemnt density 1216.78 pAm/mm2
# Prior 1. Average Mean (over dist of FWHM from centre) moment density 655.24, sd 0.00 pAm/mm2
# Prior 1. Average Peak (max vertex) moment density 1216.78, sd 0.00 pAm/mm2
# Saving /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24585_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo/prior777361.mat
# Setting white noise to give sensor level SNR of -5B
# Assembling 1 prior components
# end assemble
#
#  Finish

# %% [markdown]
# ## Model comparison (pial - white matter)
# Now we can run model comparison between source models based on the pial and white matter surfaces using cross-validation error. For computing cross-validation error, we'll run 10 folds, leaving out 10% of the channels in each fold. We'll then look at the difference in cross-validation error between the two models (pial - white matter). This should be lower for the pial surface model because we simulated activity on the pial surface

# %%
# Number of cross validation folds
n_folds = 10
# Percentage of test channels in cross validation
ideal_pc_test = 10 # may not use this number as we need integer number of channels

# Run model comparison between the first layer (pial) and the last layer (white matter)
[_,cvErr] = model_comparison(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    [layer_fnames[0], layer_fnames[-1]], 
    pial_sim_fname, 
    spm_instance=spm,
    invert_kwargs={
        'patch_size': patch_size, 
        'n_temp_modes': n_temp_modes, 
        'n_folds': n_folds, 
        'ideal_pc_test': ideal_pc_test    
    }
)
    
# The difference in cross validation error after averaging over test channels and folds
# This value should be negative (less error for the pial layer model)
np.mean(np.mean(cvErr[0],axis=-1),axis=-1)-np.mean(np.mean(cvErr[1],axis=-1),axis=-1)
# Out:
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 09:59:29 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 09:59:29 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           09:59:46 - 22/07/2024
# ========================================================================
# pial.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           10:00:15 - 22/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          10:00:15 - 22/07/2024
# computing surface normals
# 22-Jul-2024 10:00:17 - Done    'Head model specification'
# 22-Jul-2024 10:00:17 - Done
#
# Smoothing ../test_data/sub-104/surf/pial.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '../test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat'
#
#
# Found smoothfile ../test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      10:00:18 - 22/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24585_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 10:00:44 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 10:00:45 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24585_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.21 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.887201e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.775823e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.536197e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.057080e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.472881e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.778133e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.970047e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.130715e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.887201e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.775823e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.536197e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.057080e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.472881e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.778133e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.970047e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.130715e-03 [+5.00]
# Percent variance explained 99.98 (55.20)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8597e+05
#            ID: 545.4358
#            R2: 99.9831
#            VE: 55.2034
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8597e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8597e+05
#            ID: 545.4358
#            R2: 99.9831
#            VE: 55.2034
#
#
#  Cross val iteration 1 of 10, first two chans:13, 274..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.35 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891421e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.787781e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.562137e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.098964e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.622927e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.445714e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.598815e-01 [+4.88]
#   ReML Iteration 8                      :        ...5.894078e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891421e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.787781e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.562137e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.098964e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.622927e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.445714e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.598815e-01 [+4.88]
#   ReML Iteration 8                      :        ...5.894078e-03 [+5.00]
# Percent variance explained 99.98 (56.34)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8461e+05
#            ID: 554.3736
#            R2: 99.9813
#            VE: 56.3411
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8461e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8461e+05
#            ID: 554.3736
#            R2: 99.9813
#            VE: 56.3411
#
#
#  Cross val iteration 2 of 10, first two chans:1, 136..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.70 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.889128e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.782882e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.561487e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.126566e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.129991e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.970208e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.611600e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.708600e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.065409e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.889128e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.782882e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.561487e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.126566e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.129991e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.970208e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.611600e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.708600e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.065409e-03 [+5.12]
# Percent variance explained 99.99 (58.70)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8717e+05
#            ID: 578.3315
#            R2: 99.9869
#            VE: 58.6960
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8717e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8717e+05
#            ID: 578.3315
#            R2: 99.9869
#            VE: 58.6960
#
#
#  Cross val iteration 3 of 10, first two chans:115, 107..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.37 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.892943e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.793265e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.575375e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.123705e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.930927e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.801767e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.915332e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.991867e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.892943e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.793265e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.575375e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.123705e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.930927e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.801767e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.915332e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.991867e-03 [+5.00]
# Percent variance explained 99.98 (57.36)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8427e+05
#            ID: 559.8196
#            R2: 99.9784
#            VE: 57.3594
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8427e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8427e+05
#            ID: 559.8196
#            R2: 99.9784
#            VE: 57.3594
#
#
#  Cross val iteration 4 of 10, first two chans:71, 140..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.75 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.890511e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.786642e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.571120e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.147853e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.363751e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.233692e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.524251e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.823231e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.258914e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.890511e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.786642e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.571120e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.147853e+04 [+4.50]
#   ReML Iteration 5                      :        ...7.363751e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.233692e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.524251e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.823231e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.258914e-03 [+5.12]
# Percent variance explained 99.99 (59.75)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8742e+05
#            ID: 577.5384
#            R2: 99.9856
#            VE: 59.7463
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8742e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8742e+05
#            ID: 577.5384
#            R2: 99.9856
#            VE: 59.7463
#
#
#  Cross val iteration 5 of 10, first two chans:210, 57..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.00 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.892910e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.791457e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.576228e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.144526e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.319432e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.286860e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.468731e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.484043e-02 [+5.00]
#   ReML Iteration 9                      :        ...8.470295e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.892910e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.791457e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.576228e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.144526e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.319432e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.286860e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.468731e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.484043e-02 [+5.00]
#   ReML Iteration 9                      :        ...8.470295e-04 [+5.12]
# Percent variance explained 99.98 (58.99)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8614e+05
#            ID: 573.0876
#            R2: 99.9835
#            VE: 58.9880
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8614e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8614e+05
#            ID: 573.0876
#            R2: 99.9835
#            VE: 58.9880
#
#
#  Cross val iteration 6 of 10, first two chans:221, 78..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.42 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891345e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.787373e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.561794e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.100403e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.068658e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.522059e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.001436e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.798859e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891345e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.787373e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.561794e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.100403e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.068658e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.522059e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.001436e-01 [+4.88]
#   ReML Iteration 8                      :        ...8.798859e-03 [+5.00]
# Percent variance explained 99.98 (56.41)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8477e+05
#            ID: 566.3162
#            R2: 99.9825
#            VE: 56.4144
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8477e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8477e+05
#            ID: 566.3162
#            R2: 99.9825
#            VE: 56.4144
#
#
#  Cross val iteration 7 of 10, first two chans:264, 97..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.31 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.891885e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.788031e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564980e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.115000e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.907083e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.758134e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.382564e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.309067e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.811371e-04 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.891885e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.788031e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.564980e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.115000e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.907083e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.758134e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.382564e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.309067e-02 [+5.00]
#   ReML Iteration 9                      :        ...6.811371e-04 [+5.12]
# Percent variance explained 99.98 (57.30)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8542e+05
#            ID: 542.6285
#            R2: 99.9844
#            VE: 57.2974
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8542e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8542e+05
#            ID: 542.6285
#            R2: 99.9844
#            VE: 57.2974
#
#
#  Cross val iteration 8 of 10, first two chans:244, 230..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.25 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.892817e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.790530e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.572133e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.133228e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.529274e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.625056e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.875337e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.892339e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.179610e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.892817e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.790530e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.572133e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.133228e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.529274e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.625056e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.875337e-01 [+4.88]
#   ReML Iteration 8                      :        ...1.892339e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.179610e-03 [+5.12]
# Percent variance explained 99.99 (58.25)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8579e+05
#            ID: 558.4815
#            R2: 99.9858
#            VE: 58.2453
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8579e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8579e+05
#            ID: 558.4815
#            R2: 99.9858
#            VE: 58.2453
#
#
#  Cross val iteration 9 of 10, first two chans:155, 209..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 59.25 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.894712e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.795602e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.584261e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.157440e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.837546e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.240523e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.160298e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.398297e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.724537e-03 [+5.12]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.894712e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.795602e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.584261e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.157440e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.837546e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.240523e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.160298e-01 [+4.88]
#   ReML Iteration 8                      :        ...2.398297e-02 [+5.00]
#   ReML Iteration 9                      :        ...1.724537e-03 [+5.12]
# Percent variance explained 99.99 (59.25)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8578e+05
#            ID: 578.6897
#            R2: 99.9861
#            VE: 59.2461
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8578e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8578e+05
#            ID: 578.6897
#            R2: 99.9861
#            VE: 59.2461
#
#
#  Cross val iteration 10 of 10, first two chans:82, 41..
# Running cross val..22-Jul-2024 10:03:34 - Done    'Source inversion, iterative'
# 22-Jul-2024 10:03:34 - Done
#
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 10:03:36 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 10:03:36 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           10:03:38 - 22/07/2024
# ========================================================================
# white.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           10:04:06 - 22/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          10:04:06 - 22/07/2024
# computing surface normals
# 22-Jul-2024 10:04:08 - Done    'Head model specification'
# 22-Jul-2024 10:04:08 - Done
#
# Smoothing ../test_data/sub-104/surf/white.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '../test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat'
#
#
# Found smoothfile ../test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      10:04:09 - 22/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24585_pial_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# ...
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0110e+05
#            ID: 557.0293
#            R2: 99.9673
#            VE: 57.9252
#
#
#  Cross val iteration 6 of 10, first two chans:253, 110..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.68 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.742598e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.564647e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.299621e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.845968e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.106143e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.111713e-02 [+4.75]
#   ReML Iteration 7                      :        ...1.661560e-04 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.742598e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.564647e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.299621e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.845968e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.106143e+02 [+4.62]
#   ReML Iteration 6                      :        ...6.111713e-02 [+4.75]
#   ReML Iteration 7                      :        ...1.661560e-04 [+4.88]
# Percent variance explained 99.97 (56.66)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0008e+05
#            ID: 546.6325
#            R2: 99.9747
#            VE: 56.6614
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0008e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0008e+05
#            ID: 546.6325
#            R2: 99.9747
#            VE: 56.6614
#
#
#  Cross val iteration 7 of 10, first two chans:218, 196..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.66 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.727554e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.547672e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.283507e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.840225e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.741395e+01 [+4.62]
#   ReML Iteration 6                      :        ...7.983721e-03 [+4.75]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.727554e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.547672e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.283507e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.840225e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.741395e+01 [+4.62]
#   ReML Iteration 6                      :        ...7.983721e-03 [+4.75]
# Percent variance explained 99.97 (58.64)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0230e+05
#            ID: 563.4539
#            R2: 99.9653
#            VE: 58.6353
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0230e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0230e+05
#            ID: 563.4539
#            R2: 99.9653
#            VE: 58.6353
#
#
#  Cross val iteration 8 of 10, first two chans:17, 163..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.83 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.709199e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.524054e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.250443e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.781309e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.080418e+04 [+4.62]
#   ReML Iteration 6                      :        ...5.144068e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.124242e-04 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.709199e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.524054e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.250443e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.781309e+04 [+4.50]
#   ReML Iteration 5                      :        ...1.080418e+04 [+4.62]
#   ReML Iteration 6                      :        ...5.144068e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.124242e-04 [+4.88]
# Percent variance explained 99.96 (55.81)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0219e+05
#            ID: 548.8887
#            R2: 99.9647
#            VE: 55.8143
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0219e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0219e+05
#            ID: 548.8887
#            R2: 99.9647
#            VE: 55.8143
#
#
#  Cross val iteration 9 of 10, first two chans:203, 65..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.66 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.749735e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.573875e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.308587e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.859386e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.924502e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.308895e-02 [+4.75]
#   ReML Iteration 7                      :        ...1.675105e-06 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.749735e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.573875e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.308587e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.859386e+04 [+4.50]
#   ReML Iteration 5                      :        ...2.924502e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.308895e-02 [+4.75]
#   ReML Iteration 7                      :        ...1.675104e-06 [+4.88]
# Percent variance explained 99.96 (58.64)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0105e+05
#            ID: 574.9872
#            R2: 99.9646
#            VE: 58.6372
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -3.0105e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -3.0105e+05
#            ID: 574.9872
#            R2: 99.9646
#            VE: 58.6372
#
#
#  Cross val iteration 10 of 10, first two chans:244, 93..
# Running cross val..22-Jul-2024 10:07:23 - Done    'Source inversion, iterative'
# 22-Jul-2024 10:07:23 - Done
# -2.9052589777810205

# %% [markdown]
# ## White matter surface simulation with pial - white matter model comparison
# Let's simulate the same pattern of activity, in the same location, but on the white matter surface. This time, model comparison should yield lower cross-validation error for the white matter surface.

# %%
# Simulate at the corresponding vertex on the white matter surface
white_vertex = (n_layers-1)*verts_per_surf+sim_vertex
prefix = f'sim_{sim_vertex}_white_'

# Generate simulated data
white_sim_fname = run_current_density_simulation(
    base_fname, 
    prefix, 
    white_vertex, 
    sim_signal, 
    dipole_moment, 
    sim_patch_size, 
    SNR,
    spm_instance=spm
) 

# Run model comparison between the first layer (pial) and the last layer (white matter)
[_,cvErr] = model_comparison(
    nas, 
    lpa, 
    rpa, 
    mri_fname, 
    [layer_fnames[0], layer_fnames[-1]], 
    white_sim_fname, 
    spm_instance=spm,
    invert_kwargs={
        'patch_size': patch_size, 
        'n_temp_modes': n_temp_modes, 
        'n_folds': n_folds, 
        'ideal_pc_test': ideal_pc_test    
    }
)

# The difference in cross validation error after averaging over test channels and folds
# This value should be positive (less error for the white matter layer model)
np.mean(np.mean(cvErr[0],axis=-1),axis=-1)-np.mean(np.mean(cvErr[1],axis=-1),axis=-1)
# Out:
# Simulating data on MEG channels only
# Using closest mesh vertices to the specified coordinates
# Furthest distance from dipole location to mesh 0.00 mm
#
# ans =
#
#     'm'
#
# SIMULATING CURRENT DISTRIBUTIONS ON MESH
# Computing Gain Matrix:  - done
# Saving prior in directory /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24585_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo
# Using 1 iterations of 1 fixed patches
#
#  In last iteration...setting up patch 1 with  10.00 nAm , FWHM 5.00mm, mean moment density 522.28 pAm/mm2, peak momemnt density 1293.99 pAm/mm2
# Prior 1. Average Mean (over dist of FWHM from centre) moment density 522.28, sd 0.00 pAm/mm2
# Prior 1. Average Peak (max vertex) moment density 1293.99, sd 0.00 pAm/mm2
# Saving /scratch/bonaiuto/simulated_data/model_comp_cverr/simprior_sim_24585_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo/prior182056.mat
# Setting white noise to give sensor level SNR of -5B
# Assembling 1 prior components
# end assemble
#
#  Finish
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 10:12:52 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 10:12:52 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           10:13:07 - 22/07/2024
# ========================================================================
# pial.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           10:13:32 - 22/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          10:13:32 - 22/07/2024
# computing surface normals
# 22-Jul-2024 10:13:34 - Done    'Head model specification'
# 22-Jul-2024 10:13:34 - Done
#
# Smoothing ../test_data/sub-104/surf/pial.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '../test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat'
#
#
# Found smoothfile ../test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      10:13:35 - 22/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24585_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 10:13:57 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 10:13:57 - Running 'Source inversion, iterative'
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_sim_24585_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.55 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.815671e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.666321e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.415299e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.952177e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.068525e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.713865e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.216068e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.083403e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.815671e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.666321e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.415299e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.952177e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.068525e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.713865e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.216068e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.083403e-04 [+5.00]
# Percent variance explained 99.98 (56.55)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8067e+05
#            ID: 443.7912
#            R2: 99.9839
#            VE: 56.5453
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8067e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8067e+05
#            ID: 443.7912
#            R2: 99.9839
#            VE: 56.5453
#  Cross val iteration 1 of 10, first two chans:222, 214..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.99 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.801649e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.643161e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.376694e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.883742e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.872123e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.663982e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.354140e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.334167e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.801649e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.643161e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.376694e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.883742e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.872123e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.663982e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.354140e-02 [+4.88]
#   ReML Iteration 8                      :        ...5.334167e-04 [+5.00]
# Percent variance explained 99.98 (53.98)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8137e+05
#            ID: 439.7223
#            R2: 99.9836
#            VE: 53.9831
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8137e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8137e+05
#            ID: 439.7223
#            R2: 99.9836
#            VE: 53.9831
#
#
#  Cross val iteration 2 of 10, first two chans:171, 186..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 58.10 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.794224e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.640572e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395514e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.951210e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.222567e+02 [+4.62]
#   ReML Iteration 6                      :        ...9.377193e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.973207e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.619380e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.794224e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.640572e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395514e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.951210e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.222567e+02 [+4.62]
#   ReML Iteration 6                      :        ...9.377193e-01 [+4.75]
#   ReML Iteration 7                      :        ...1.973207e-02 [+4.88]
#   ReML Iteration 8                      :        ...4.619380e-04 [+5.00]
# Percent variance explained 99.98 (58.09)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8304e+05
#            ID: 465.1544
#            R2: 99.9838
#            VE: 58.0929
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8304e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8304e+05
#            ID: 465.1544
#            R2: 99.9838
#            VE: 58.0929
#
#
#  Cross val iteration 3 of 10, first two chans:151, 227..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 52.91 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.791074e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.628517e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.353775e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.844592e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.125038e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.475385e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.015121e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.153176e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.791074e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.628517e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.353775e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.844592e+04 [+4.50]
#   ReML Iteration 5                      :        ...4.125038e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.475385e+00 [+4.75]
#   ReML Iteration 7                      :        ...2.015121e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.153176e-04 [+5.00]
# Percent variance explained 99.98 (52.90)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8203e+05
#            ID: 427.5149
#            R2: 99.9839
#            VE: 52.8966
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8203e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8203e+05
#            ID: 427.5149
#            R2: 99.9839
#            VE: 52.8966
#
#
#  Cross val iteration 4 of 10, first two chans:242, 246..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.98 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.804257e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.653135e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.410288e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.966980e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.757299e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.377387e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.254290e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.712980e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.804257e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.653135e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.410288e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.966980e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.757299e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.377387e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.254290e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.712980e-04 [+5.00]
# Percent variance explained 99.98 (57.97)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8210e+05
#            ID: 464.7637
#            R2: 99.9849
#            VE: 57.9731
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8210e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8210e+05
#            ID: 464.7637
#            R2: 99.9849
#            VE: 57.9731
#
#
#  Cross val iteration 5 of 10, first two chans:183, 89..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.15 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.796933e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.645328e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395409e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.930227e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.444786e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.932993e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.727733e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.469890e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.796933e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.645328e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395409e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.930227e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.444786e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.932993e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.727733e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.469890e-04 [+5.00]
# Percent variance explained 99.98 (56.14)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8171e+05
#            ID: 444.4602
#            R2: 99.9849
#            VE: 56.1382
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8171e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8171e+05
#            ID: 444.4602
#            R2: 99.9849
#            VE: 56.1382
#
#
#  Cross val iteration 6 of 10, first two chans:252, 109..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.56 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.792262e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.638508e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.384660e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.912429e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.277472e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.964977e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.478228e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.304807e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.792262e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.638508e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.384660e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.912429e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.277472e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.964977e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.478228e-02 [+4.88]
#   ReML Iteration 8                      :        ...7.304807e-04 [+5.00]
# Percent variance explained 99.99 (55.55)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8199e+05
#            ID: 437.6701
#            R2: 99.9857
#            VE: 55.5494
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8199e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8199e+05
#            ID: 437.6701
#            R2: 99.9857
#            VE: 55.5494
#
#
#  Cross val iteration 7 of 10, first two chans:217, 195..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 55.76 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.754661e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.584753e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.322372e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.855978e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.015457e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.154358e-01 [+4.75]
#   ReML Iteration 7                      :        ...4.133889e-03 [+4.88]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.754661e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.584753e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.322372e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.855978e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.015457e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.154358e-01 [+4.75]
#   ReML Iteration 7                      :        ...4.133889e-03 [+4.88]
# Percent variance explained 99.98 (55.75)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8501e+05
#            ID: 438.2361
#            R2: 99.9815
#            VE: 55.7518
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8501e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8501e+05
#            ID: 438.2361
#            R2: 99.9815
#            VE: 55.7518
#
#
#  Cross val iteration 8 of 10, first two chans:16, 162..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 57.12 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.794480e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.641955e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395379e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.941326e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.678743e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.549736e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.383514e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.469370e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.794480e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.641955e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.395379e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.941326e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.678743e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.549736e+00 [+4.75]
#   ReML Iteration 7                      :        ...3.383514e-02 [+4.88]
#   ReML Iteration 8                      :        ...8.469370e-04 [+5.00]
# Percent variance explained 99.99 (57.12)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8251e+05
#            ID: 449.1231
#            R2: 99.9853
#            VE: 57.1162
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8251e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8251e+05
#            ID: 449.1231
#            R2: 99.9853
#            VE: 57.1162
#
#
#  Cross val iteration 9 of 10, first two chans:202, 64..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_pial.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.61 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.783965e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623832e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.355851e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.857965e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.834002e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.989180e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.502045e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.456714e-04 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.783965e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.623832e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.355851e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.857965e+04 [+4.50]
#   ReML Iteration 5                      :        ...3.834002e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.989180e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.502045e-02 [+4.88]
#   ReML Iteration 8                      :        ...1.456714e-04 [+5.00]
# Percent variance explained 99.98 (53.60)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8211e+05
#            ID: 430.8618
#            R2: 99.9829
#            VE: 53.5994
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.8211e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.8211e+05
#            ID: 430.8618
#            R2: 99.9829
#            VE: 53.5994
#
#
#  Cross val iteration 10 of 10, first two chans:243, 92..
# Running cross val..22-Jul-2024 10:16:29 - Done    'Source inversion, iterative'
# 22-Jul-2024 10:16:29 - Done
#
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Defaults settings have been modified by file(s):
#   /home/bonaiuto/.mcrCache9.6/spm_st0/spm_standalo/spm_my_defaults.m
# Modified fields: use_parfor mat
#
#
# ------------------------------------------------------------------------
# 22-Jul-2024 10:16:30 - Running job #1
# ------------------------------------------------------------------------
# 22-Jul-2024 10:16:30 - Running 'Head model specification'
#
# SPM: spm_eeg_inv_mesh_ui                           10:16:32 - 22/07/2024
# ========================================================================
# white.ds.link_vector.fixed
# undoing the G3BR balancing for the gradiometer definition
# creating layout from cfg.grad
# undoing the G3BR balancing for the gradiometer definition
# creating layout for ctf275 system
#
# SPM: spm_eeg_inv_forward                           10:17:01 - 22/07/2024
# ========================================================================
# Warning: amplitude, distance and scaling are not supported for version "2011v2"
# Completed                               :          10:17:01 - 22/07/2024
# computing surface normals
# 22-Jul-2024 10:17:03 - Done    'Head model specification'
# 22-Jul-2024 10:17:03 - Done
#
# Smoothing ../test_data/sub-104/surf/white.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '../test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat'
#
#
# Found smoothfile ../test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Adjusting pc test from 10.00 to 9.85 percent to make use of most MEG channels
# Using maximum of 247 spatial modes
#
#         SPM: spm_eeg_lgainmat                      10:17:04 - 22/07/2024
#         ----------------------------------------------------------------
# computing surface normals
#
# Preparing modes file  block 1 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 2 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 3 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 4 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 5 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 6 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 7 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 8 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 9 of 10 for 247 training and 27 test chans
#
# Preparing modes file  block 10 of 10 for 247 training and 27 test chans
#
#  saving spatial mode file /scratch/bonaiuto/simulated_data/model_comp_cverr/sim_24585_white_spm-converted_autoreject-sub-104-ses-01-001-btn_trial-epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# ...
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 54.73 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.872073e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.747068e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.495359e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.009935e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.356309e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.223977e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.190079e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.692551e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.872073e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.747068e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.495359e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.009935e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.356309e+02 [+4.62]
#   ReML Iteration 6                      :        ...5.223977e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.190079e-01 [+4.88]
#   ReML Iteration 8                      :        ...3.692551e-03 [+5.00]
# Percent variance explained 99.99 (54.72)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7448e+05
#            ID: 431.8405
#            R2: 99.9864
#            VE: 54.7202
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7448e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7448e+05
#            ID: 431.8405
#            R2: 99.9864
#            VE: 54.7202
#
#
#  Cross val iteration 7 of 10, first two chans:218, 196..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.55 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.883670e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.770277e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.534605e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.072831e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.130862e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.674077e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.859069e-01 [+4.88]
#   ReML Iteration 8                      :        ...9.403431e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.883670e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.770277e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.534605e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.072831e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.130862e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.674077e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.859069e-01 [+4.88]
#   ReML Iteration 8                      :        ...9.403431e-03 [+5.00]
# Percent variance explained 99.99 (56.55)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7319e+05
#            ID: 443.5297
#            R2: 99.9864
#            VE: 56.5456
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7319e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7319e+05
#            ID: 443.5297
#            R2: 99.9864
#            VE: 56.5456
#
#
#  Cross val iteration 8 of 10, first two chans:17, 163..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 53.84 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.865407e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.733400e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.471675e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.972513e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.084422e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.838725e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.095965e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.342277e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.865407e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.733400e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.471675e+04 [+4.38]
#   ReML Iteration 4                      :        ...1.972513e+04 [+4.50]
#   ReML Iteration 5                      :        ...5.084422e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.838725e+00 [+4.75]
#   ReML Iteration 7                      :        ...9.095965e-02 [+4.88]
#   ReML Iteration 8                      :        ...2.342277e-03 [+5.00]
# Percent variance explained 99.99 (53.83)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7551e+05
#            ID: 432.5567
#            R2: 99.9850
#            VE: 53.8309
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7551e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7551e+05
#            ID: 432.5567
#            R2: 99.9850
#            VE: 53.8309
#
#
#  Cross val iteration 9 of 10, first two chans:203, 65..
# Running cross val..Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.9628    0.7927
#     0.8747    0.4015
#
#  - done
#
# Found smoothfile /home/bonaiuto/laMEG/test_data/sub-104/surf/FWHM5.00_white.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using pre-specified spatial modes
# Using 247 spatial modesNumber of samples 601
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 56.68 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.877176e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.758259e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.518666e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.057020e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.010571e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.485381e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.487402e-01 [+4.88]
#   ReML Iteration 8                      :        ...6.290959e-03 [+5.00]
# Inverting subject 1
#
# ans =
#
#    240
#
#
# ans =
#
#    247
#
# Warning: AYYA IS RANK DEFICIENT
#   ReML Iteration 1                      :        ...2.877176e+04 [+4.12]
#   ReML Iteration 2                      :        ...2.758259e+04 [+4.25]
#   ReML Iteration 3                      :        ...2.518666e+04 [+4.38]
#   ReML Iteration 4                      :        ...2.057020e+04 [+4.50]
#   ReML Iteration 5                      :        ...6.010571e+02 [+4.62]
#   ReML Iteration 6                      :        ...4.485381e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.487402e-01 [+4.88]
#   ReML Iteration 8                      :        ...6.290959e-03 [+5.00]
# Percent variance explained 99.99 (56.68)
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: 0
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7443e+05
#            ID: 452.8631
#            R2: 99.9867
#            VE: 56.6771
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [-500 500]
#           Han: 0
#           lpf: 0
#           hpf: 256
#     mergeflag: 0
#            Np: 512
#            Nm: 247
#            Nt: 4
#        smooth: 5
#      modality: 'MEG'
#          allF: -2.7443e+05
#       PostMax: [49733x1 double]
#             A: [247x247 double]
#            Ip: [1x512 double]
#             M: [49733x247 double]
#             J: {[49733x4 double]}
#             Y: [247x4 double]
#             L: [247x49733 double]
#            qC: [49733x1 double]
#         tempU: [513x513 double]
#             V: [513x4 double]
#            qV: [601x601 double]
#             T: [601x4 double]
#             U: {[247x247 double]}
#            Is: [1x49733 double]
#            It: [1x601 double]
#            Ik: [1x60 double]
#            Ic: {[1x247 double]}
#            Nd: 49733
#           pst: [1x601 double]
#           dct: [1x513 double]
#             F: -2.7443e+05
#            ID: 452.8631
#            R2: 99.9867
#            VE: 56.6771
#
#
#  Cross val iteration 10 of 10, first two chans:244, 93..
# Running cross val..22-Jul-2024 10:19:59 - Done    'Source inversion, iterative'
# 22-Jul-2024 10:19:59 - Done
# 1.1529758274587714

# %% [markdown]
# ## Simulation in each layer with model comparison across layers
# That was model comparison with two candidate models: one based on the white matter surface, and one on the pial. Let's now simulate on each layer, and for each simulation, run model comparison across all layers. We'll turn off SPM visualization here.

# %%
# Now simulate at the corresponding vertex on each layer, and for each simulation, run model comparison across
# all layers
all_layerCvErr = []

for l in range(n_layers):
    print(f'Simulating in layer {l}')
    l_vertex = l*verts_per_surf+sim_vertex
    prefix = f'sim_{sim_vertex}_{l}_'

    l_sim_fname = run_current_density_simulation(
        base_fname, 
        prefix, 
        l_vertex, 
        sim_signal, 
        dipole_moment, 
        sim_patch_size, 
        SNR,
        spm_instance=spm
    ) 

    [_,layerCvErr] = model_comparison(
        nas, 
        lpa, 
        rpa, 
        mri_fname, 
        layer_fnames, 
        l_sim_fname, 
        viz=False,
        spm_instance=spm,
        invert_kwargs={
            'patch_size': patch_size, 
            'n_temp_modes': n_temp_modes, 
            'n_folds': n_folds, 
            'ideal_pc_test': ideal_pc_test    
        }
    )
    all_layerCvErr.append(layerCvErr)    
all_layerCvErr = np.array(all_layerCvErr)

# Average over test channels and folds
all_layerCvErr = np.mean(np.mean(all_layerCvErr, axis=-1), axis=-1)

# %% [markdown]
# For each simulation, we can plot the cross-validation error for all models relative to the worst model. The layer model with the lowest cross-validation error should correspond to the layer that the activity was simulated in.

# %%
col_r = plt.cm.cool(np.linspace(0,1, num=n_layers))
plt.figure(figsize=(10,4))

# For each simulation, plot the CV error of each layer model relative to that of the worst
# model for that simulation
plt.subplot(1,2,1)
for l in range(n_layers):
    layerCvErr=all_layerCvErr[l,:]
    plt.plot(layerCvErr, label=f'{l}', color=col_r[l,:])
plt.legend()
plt.xlabel('Eval layer')
plt.ylabel('CVErr')

# For each simulation, find which layer model had the lowest CV error
plt.subplot(1,2,2)
peaks=[]
for l in range(n_layers):
    layerCvErr=all_layerCvErr[l,:]
    pk=np.argmin(layerCvErr)
    peaks.append(pk)
plt.plot(peaks)
plt.xlim([-0.5,10.5])
plt.ylim([-0.5,10.5])
plt.plot([0,10],[0,10],'k--')
plt.xlabel('Sim layer')
plt.ylabel('Min CVErr')
plt.tight_layout()

# %%
# Normalization step
norm_layerCvErr = np.zeros(all_layerCvErr.shape)
for l in range(n_layers):
    norm_layerCvErr[l,:] = all_layerCvErr[l,:] - np.max(all_layerCvErr[l,:])
norm_layerCvErr=-1*norm_layerCvErr

# Transpose for visualization
im=plt.imshow(norm_layerCvErr.T)

# Find the indices of the max value in each column
max_indices = np.argmax(norm_layerCvErr, axis=1)

# Plot an 'X' at the center of the square for each column's maximum
for idx, max_idx in enumerate(max_indices):
    plt.text(idx, max_idx, 'X', fontsize=12, ha='center', va='center', color='black', weight='bold')

plt.xlabel('Simulated layer', fontsize=14)
plt.ylabel('Evaluated layer', fontsize=14)
cb=plt.colorbar(im)
cb.set_label('CVerr', fontsize=14)

# %%
spm.terminate()

# Delete simulation files

# Iterate over all items in the directory
for item in os.listdir(tmp_dir):
    item_path = os.path.join(tmp_dir, item)

    # Check if it's a file or a directory
    if os.path.isfile(item_path):
        # Delete the file
        os.remove(item_path)
    elif os.path.isdir(item_path):
        # Recursively delete the directory
        shutil.rmtree(item_path)
